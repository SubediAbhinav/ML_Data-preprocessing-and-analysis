# %%
import numpy as np

# %%
import pandas as pd

# %%
heart_data=pd.read_csv("heart_disease.csv")

# %%
heart_data
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 0               30.0          No  Female        55-59     White      Yes
# 1                0.0          No  Female  80 or older     White       No
# 2               30.0          No    Male        65-69     White      Yes
# 3                0.0          No  Female        75-79     White       No
# 4                0.0         Yes  Female        40-44     White       No
# ...              ...         ...     ...          ...       ...      ...
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0                   Yes  Very good        5.0    Yes            No        Yes
# 1                   Yes  Very good        7.0     No            No         No
# 2                   Yes       Fair        8.0    Yes            No         No
# 3                    No       Good        6.0     No            No        Yes
# 4                   Yes  Very good        8.0     No            No         No
# ...                 ...        ...        ...    ...           ...        ...
# 319790               No       Fair        6.0    Yes            No         No
# 319791              Yes  Very good        5.0    Yes            No         No
# 319792              Yes       Good        6.0     No            No         No
# 319793               No       Good       12.0     No            No         No
# 319794              Yes       Good        8.0     No            No         No
#
# [319795 rows x 18 columns]

# %%
heart_data.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319789 non-null  float64
#  2   Smoking           319721 non-null  object
#  3   AlcoholDrinking   319680 non-null  object
#  4   Stroke            319774 non-null  object
#  5   PhysicalHealth    319778 non-null  float64
#  6   MentalHealth      319781 non-null  float64
#  7   DiffWalking       319762 non-null  object
#  8   Sex               319482 non-null  object
#  9   AgeCategory       319751 non-null  object
#  10  Race              319756 non-null  object
#  11  Diabetic          319762 non-null  object
#  12  PhysicalActivity  319779 non-null  object
#  13  GenHealth         319302 non-null  object
#  14  SleepTime         319576 non-null  float64
#  15  Asthma            319795 non-null  object
#  16  KidneyDisease     319778 non-null  object
#  17  SkinCancer        319795 non-null  object
# dtypes: float64(4), object(14)
# memory usage: 43.9+ MB

# %%
heart_data.describe
# Out:
# <bound method NDFrame.describe of        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 0               30.0          No  Female        55-59     White      Yes
# 1                0.0          No  Female  80 or older     White       No
# 2               30.0          No    Male        65-69     White      Yes
# 3                0.0          No  Female        75-79     White       No
# 4                0.0         Yes  Female        40-44     White       No
# ...              ...         ...     ...          ...       ...      ...
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0                   Yes  Very good        5.0    Yes            No        Yes
# 1                   Yes  Very good        7.0     No            No         No
# 2                   Yes       Fair        8.0    Yes            No         No
# 3                    No       Good        6.0     No            No        Yes
# 4                   Yes  Very good        8.0     No            No         No
# ...                 ...        ...        ...    ...           ...        ...
# 319790               No       Fair        6.0    Yes            No         No
# 319791              Yes  Very good        5.0    Yes            No         No
# 319792              Yes       Good        6.0     No            No         No
# 319793               No       Good       12.0     No            No         No
# 319794              Yes       Good        8.0     No            No         No
#
# [319795 rows x 18 columns]>

# %%
heart_data.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319789.000000   319778.000000  319781.000000  319576.000000
# mean       28.325348        3.371605       3.898384       7.096922
# std         6.356134        7.950662       7.955291       1.436165
# min        12.020000        0.000000       0.000000       1.000000
# 25%        24.030000        0.000000       0.000000       6.000000
# 50%        27.340000        0.000000       0.000000       7.000000
# 75%        31.420000        2.000000       3.000000       8.000000
# max        94.850000       30.000000      30.000000      24.000000

# %%
heart_data.isna()
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0              False  False    False            False   False           False
# 1              False  False    False            False   False           False
# 2              False  False    False            False   False           False
# 3              False  False    False            False   False           False
# 4              False  False    False            False   False           False
# ...              ...    ...      ...              ...     ...             ...
# 319790         False  False    False            False   False           False
# 319791         False  False    False            False   False           False
# 319792         False  False    False            False   False           False
# 319793         False  False    False            False   False           False
# 319794         False  False    False            False   False           False
#
#         MentalHealth  DiffWalking    Sex  AgeCategory   Race  Diabetic  \
# 0              False        False  False        False  False     False
# 1              False        False  False        False  False     False
# 2              False        False  False        False  False     False
# 3              False        False  False        False  False     False
# 4              False        False  False        False  False     False
# ...              ...          ...    ...          ...    ...       ...
# 319790         False        False  False        False  False     False
# 319791         False        False  False        False  False     False
# 319792         False        False  False        False  False     False
# 319793         False        False  False        False  False     False
# 319794         False        False  False        False  False     False
#
#         PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  \
# 0                  False      False      False   False          False
# 1                  False      False      False   False          False
# 2                  False      False      False   False          False
# 3                  False      False      False   False          False
# 4                  False      False      False   False          False
# ...                  ...        ...        ...     ...            ...
# 319790             False      False      False   False          False
# 319791             False      False      False   False          False
# 319792             False      False      False   False          False
# 319793             False      False      False   False          False
# 319794             False      False      False   False          False
#
#         SkinCancer
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 319790       False
# 319791       False
# 319792       False
# 319793       False
# 319794       False
#
# [319795 rows x 18 columns]

# %%
heart_data.isna().sum()
# Out:
# HeartDisease          0
# BMI                   6
# Smoking              74
# AlcoholDrinking     115
# Stroke               21
# PhysicalHealth       17
# MentalHealth         14
# DiffWalking          33
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease        17
# SkinCancer            0
# dtype: int64

# %%
heart_data['BMI'].fillna(heart_data['BMI'].mode()[0],inplace=True)

# %%
heart_data['BMI'].isna().sum()
# Out:
# 0

# %%
heart_data['Smoking'].fillna(heart_data['Smoking'].mode()[0],inplace=True)

# %%
fill_values = {
    'SleepTime': heart_data['SleepTime'].median(),
    'MentalHealth': heart_data['MentalHealth'].mean(),
    'PhysicalHealth': heart_data['PhysicalHealth'].median(),
    'AlcoholDrinking': heart_data['AlcoholDrinking'].mode()[0],
    'Stroke': heart_data['Stroke'].mode()[0],
    'DiffWalking': heart_data['DiffWalking'].mode()[0],
    'Sex': heart_data['Sex'].mode()[0],
    'Race': heart_data['Race'].mode()[0],
    'Diabetic': heart_data['Diabetic'].mode()[0],
    'PhysicalActivity': heart_data['PhysicalActivity'].mode()[0],
    'GenHealth': heart_data['GenHealth'].mode()[0],
    'KidneyDisease': heart_data['KidneyDisease'].mode()[0],
    'AgeCategory': heart_data['AgeCategory'].mode()[0]
}
heart_data = heart_data.fillna(fill_values)

# %%
heart_data.isna().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
heart_data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
heart_data.head(20)
# Out:
#    HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0            No  16.60     Yes              No     No             3.0
# 1            No  20.34      No              No    Yes             0.0
# 2            No  26.58     Yes              No     No            20.0
# 3            No  24.21      No              No     No             0.0
# 4            No  23.71      No              No     No            28.0
# 5           Yes  28.87     Yes              No     No             6.0
# 6            No  21.63      No              No     No            15.0
# 7            No  26.63     Yes              No     No             5.0
# 8            No  26.45      No              No     No             0.0
# 9            No  40.69      No              No     No             0.0
# 10          Yes  34.30     Yes              No     No            30.0
# 11           No  28.71     Yes              No     No             0.0
# 12           No  28.37     Yes              No     No             0.0
# 13           No  28.15      No              No     No             7.0
# 14           No  29.29     Yes              No     No             0.0
# 15           No  29.18      No              No     No             1.0
# 16           No  26.26      No              No     No             5.0
# 17           No  22.59     Yes              No     No             0.0
# 18           No  29.86     Yes              No     No             0.0
# 19           No  18.13      No              No     No             0.0
#
#     MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0           30.0          No  Female        55-59  White
# 1            0.0          No  Female  80 or older  White
# 2           30.0          No    Male        65-69  White
# 3            0.0          No  Female        75-79  White
# 4            0.0         Yes  Female        40-44  White
# 5            0.0         Yes  Female        75-79  Black
# 6            0.0          No  Female        70-74  White
# 7            0.0         Yes  Female  80 or older  White
# 8            0.0          No  Female  80 or older  White
# 9            0.0         Yes    Male        65-69  White
# 10           0.0         Yes    Male        60-64  White
# 11           0.0          No  Female        55-59  White
# 12           0.0         Yes    Male        75-79  White
# 13           0.0         Yes  Female  80 or older  White
# 14          30.0         Yes  Female        60-64  White
# 15           0.0          No  Female        50-54  White
# 16           2.0          No  Female        70-74  White
# 17          30.0         Yes    Male        70-74  White
# 18           0.0         Yes  Female        75-79  Black
# 19           0.0          No    Male  80 or older  White
#
#                    Diabetic PhysicalActivity  GenHealth  SleepTime Asthma  \
# 0                       Yes              Yes  Very good        5.0    Yes
# 1                        No              Yes  Very good        7.0     No
# 2                       Yes              Yes       Fair        8.0    Yes
# 3                        No               No       Good        6.0     No
# 4                        No              Yes  Very good        8.0     No
# 5                        No               No       Fair       12.0     No
# 6                        No              Yes       Fair        4.0    Yes
# 7                       Yes               No       Good        9.0    Yes
# 8   No, borderline diabetes               No       Fair        5.0     No
# 9                        No              Yes       Good       10.0     No
# 10                      Yes               No       Poor       15.0    Yes
# 11                       No              Yes  Very good        5.0     No
# 12                      Yes              Yes  Very good        8.0     No
# 13                       No               No       Good        7.0     No
# 14                       No               No       Good        5.0     No
# 15                       No              Yes  Very good        6.0     No
# 16                       No               No  Very good       10.0     No
# 17  No, borderline diabetes              Yes       Good        8.0     No
# 18                      Yes               No       Fair        5.0     No
# 19                       No              Yes  Excellent        8.0     No
#
#    KidneyDisease SkinCancer
# 0             No        Yes
# 1             No         No
# 2             No         No
# 3             No        Yes
# 4             No         No
# 5             No         No
# 6             No        Yes
# 7             No         No
# 8             No         No
# 9             No         No
# 10            No         No
# 11            No         No
# 12            No         No
# 13            No         No
# 14            No         No
# 15            No         No
# 16            No         No
# 17            No         No
# 18            No         No
# 19            No        Yes

# %%
heart_data.tail()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 319790               No       Fair        6.0    Yes            No         No
# 319791              Yes  Very good        5.0    Yes            No         No
# 319792              Yes       Good        6.0     No            No         No
# 319793               No       Good       12.0     No            No         No
# 319794              Yes       Good        8.0     No            No         No

# %%
heart_data.tail(30)
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 319765          Yes  38.45      No              No    Yes            30.0
# 319766           No  36.90      No              No     No             0.0
# 319767          Yes  36.21     Yes              No     No             0.0
# 319768           No  32.78      No              No     No             0.0
# 319769           No  25.25      No              No     No             0.0
# 319770           No  26.63      No              No     No             0.0
# 319771           No  23.62      No              No     No             0.0
# 319772           No  30.90      No              No     No             0.0
# 319773           No  26.45      No              No     No             3.0
# 319774           No  20.36      No              No     No            30.0
# 319775           No  24.37     Yes              No     No             0.0
# 319776           No  27.98      No              No     No             0.0
# 319777           No  42.57      No              No     No             0.0
# 319778           No  26.63      No              No     No             0.0
# 319779           No  23.38     Yes              No     No            30.0
# 319780           No  30.67      No              No     No             0.0
# 319781          Yes  37.12     Yes              No     No             0.0
# 319782           No  31.89     Yes              No     No            30.0
# 319783           No  33.28      No              No     No             0.0
# 319784           No  26.58     Yes              No     No             0.0
# 319785           No  31.93      No             Yes     No             0.0
# 319786          Yes  33.20     Yes              No     No             0.0
# 319787           No  36.54      No              No     No             7.0
# 319788           No  23.38      No              No     No             0.0
# 319789           No  22.22      No              No     No             0.0
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 319765          15.0         Yes  Female        55-59  Hispanic      Yes
# 319766           0.0         Yes  Female        55-59  Hispanic       No
# 319767           0.0         Yes  Female        75-79  Hispanic      Yes
# 319768           0.0          No    Male        45-49  Hispanic       No
# 319769           0.0          No    Male        65-69  Hispanic      Yes
# 319770           0.0          No  Female        45-49  Hispanic       No
# 319771           0.0          No    Male        25-29  Hispanic       No
# 319772           0.0          No  Female        18-24  Hispanic       No
# 319773           2.0          No  Female        18-24  Hispanic       No
# 319774           0.0         Yes  Female        55-59  Hispanic      Yes
# 319775           0.0          No    Male        35-39  Hispanic       No
# 319776           0.0          No  Female        50-54  Hispanic       No
# 319777           0.0         Yes  Female        60-64  Hispanic       No
# 319778           0.0          No  Female        25-29  Hispanic       No
# 319779           0.0         Yes  Female        70-74  Hispanic       No
# 319780           8.0          No  Female        25-29  Hispanic       No
# 319781           0.0          No    Male        35-39  Hispanic       No
# 319782          30.0         Yes  Female        55-59  Hispanic       No
# 319783           0.0          No  Female        30-34  Hispanic       No
# 319784           0.0         Yes    Male        75-79  Hispanic       No
# 319785           0.0          No    Male        65-69  Hispanic       No
# 319786           0.0          No  Female        60-64  Hispanic      Yes
# 319787           0.0          No    Male        30-34  Hispanic       No
# 319788           0.0          No  Female        60-64  Hispanic       No
# 319789           0.0          No  Female        18-24  Hispanic       No
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 319765              Yes       Poor        6.0    Yes            No         No
# 319766               No       Fair        9.0     No            No         No
# 319767              Yes       Good        8.0     No            No         No
# 319768              Yes  Very good        6.0     No            No         No
# 319769              Yes       Good        7.0     No            No         No
# 319770               No  Very good        6.0     No            No         No
# 319771              Yes       Good        7.0     No            No         No
# 319772              Yes  Excellent        7.0     No            No         No
# 319773               No       Fair        8.0     No            No         No
# 319774              Yes       Fair        8.0     No            No         No
# 319775               No       Good        8.0     No            No         No
# 319776               No       Good        8.0     No            No         No
# 319777               No       Good        7.0     No            No         No
# 319778               No  Very good        8.0     No            No         No
# 319779              Yes       Fair        5.0     No            No         No
# 319780              Yes  Very good        7.0     No            No         No
# 319781              Yes  Very good        7.0     No            No         No
# 319782               No       Fair        4.0     No            No         No
# 319783              Yes  Excellent        8.0     No            No         No
# 319784              Yes       Good        6.0     No            No         No
# 319785              Yes       Good        7.0     No            No         No
# 319786              Yes  Very good        8.0    Yes            No         No
# 319787               No       Good        9.0     No            No         No
# 319788              Yes  Excellent        6.0     No            No         No
# 319789              Yes  Excellent        8.0     No            No         No
# 319790               No       Fair        6.0    Yes            No         No
# 319791              Yes  Very good        5.0    Yes            No         No
# 319792              Yes       Good        6.0     No            No         No
# 319793               No       Good       12.0     No            No         No
# 319794              Yes       Good        8.0     No            No         No

# %%
heart_data.describe(include='object')
# Out:
#        HeartDisease Smoking AlcoholDrinking  Stroke DiffWalking     Sex  \
# count        319795  319795          319795  319795      319795  319795
# unique            2       2               2       2           2       2
# top              No      No              No      No          No  Female
# freq         292422  187917          298023  307727      275396  167904
#
#        AgeCategory    Race Diabetic PhysicalActivity  GenHealth  Asthma  \
# count       319795  319795   319795           319795     319795  319795
# unique          13       6        4                2          5       2
# top          65-69   White       No              Yes  Very good      No
# freq         34187  245228   269659           247962     114150  276923
#
#        KidneyDisease SkinCancer
# count         319795     319795
# unique             2          2
# top               No         No
# freq          308018     289976

# %%
heart_data['Stroke']
# Out:
# 0          No
# 1         Yes
# 2          No
# 3          No
# 4          No
#          ...
# 319790     No
# 319791     No
# 319792     No
# 319793     No
# 319794     No
# Name: Stroke, Length: 319795, dtype: object

# %%
heart_data['SleepTime'].min()
# Out:
# 1.0

# %%
heart_data['SleepTime'].max()
# Out:
# 24.0

# %%
heart_data['SleepTime'].mean()
# Out:
# 7.096855798245751

# %%
heart_data['SleepTime'].mode()
# Out:
# 0    7.0
# Name: SleepTime, dtype: float64

# %%
heart_data['SleepTime'].median()
# Out:
# 7.0

# %%
heart_data['SleepTime'].std()
# Out:
# 1.435675568720679

# %%
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
label_enc=LabelEncoder()

# %%
heart_data['smoking_enc'] = label_enc.fit_transform(heart_data['Smoking'])

# %%
heart_data[['smoking_enc','Smoking']]
# Out:
#         smoking_enc Smoking
# 0                 1     Yes
# 1                 0      No
# 2                 1     Yes
# 3                 0      No
# 4                 0      No
# ...             ...     ...
# 319790            1     Yes
# 319791            1     Yes
# 319792            0      No
# 319793            0      No
# 319794            0      No
#
# [319795 rows x 2 columns]

# %%
heart_data['AlcoholDrinking_enc']=label_enc.fit_transform(heart_data['AlcoholDrinking'])
heart_data['Stroke_enc']=label_enc.fit_transform(heart_data['Stroke'])
heart_data['DiffWalking_enc']=label_enc.fit_transform(heart_data['DiffWalking'])
heart_data['Sex_enc']=label_enc.fit_transform(heart_data['Sex'])
heart_data['AgeCategory_enc']=label_enc.fit_transform(heart_data['AgeCategory'])
heart_data['Race_enc']=label_enc.fit_transform(heart_data['Race'])
heart_data['Diabetic_enc']=label_enc.fit_transform(heart_data['Diabetic'])
heart_data['PhysicalActivity_enc']=label_enc.fit_transform(heart_data['PhysicalActivity'])
heart_data['GenHealth_enc']=label_enc.fit_transform(heart_data['GenHealth'])
heart_data['Asthma_enc']=label_enc.fit_transform(heart_data['Asthma'])
heart_data['KidneyDisease_enc']=label_enc.fit_transform(heart_data['KidneyDisease'])
heart_data['SkinCancer_enc']=label_enc.fit_transform(heart_data['SkinCancer'])

# %%
heart_data[['AlcoholDrinking_enc','AlcoholDrinking']]
# Out:
#         AlcoholDrinking_enc AlcoholDrinking
# 0                         0              No
# 1                         0              No
# 2                         0              No
# 3                         0              No
# 4                         0              No
# ...                     ...             ...
# 319790                    0              No
# 319791                    0              No
# 319792                    0              No
# 319793                    0              No
# 319794                    0              No
#
# [319795 rows x 2 columns]

# %%
heart_data[['Stroke_enc','Stroke']]
# Out:
#         Stroke_enc Stroke
# 0                0     No
# 1                1    Yes
# 2                0     No
# 3                0     No
# 4                0     No
# ...            ...    ...
# 319790           0     No
# 319791           0     No
# 319792           0     No
# 319793           0     No
# 319794           0     No
#
# [319795 rows x 2 columns]

# %%
heart_data[['DiffWalking_enc','DiffWalking']]
# Out:
#         DiffWalking_enc DiffWalking
# 0                     0          No
# 1                     0          No
# 2                     0          No
# 3                     0          No
# 4                     1         Yes
# ...                 ...         ...
# 319790                1         Yes
# 319791                0          No
# 319792                0          No
# 319793                0          No
# 319794                0          No
#
# [319795 rows x 2 columns]

# %%
heart_data[['Sex_enc','Sex']]
# Out:
#         Sex_enc     Sex
# 0             0  Female
# 1             0  Female
# 2             1    Male
# 3             0  Female
# 4             0  Female
# ...         ...     ...
# 319790        1    Male
# 319791        1    Male
# 319792        0  Female
# 319793        0  Female
# 319794        0  Female
#
# [319795 rows x 2 columns]

# %%
heart_data[['AgeCategory_enc','AgeCategory']]
# Out:
#         AgeCategory_enc  AgeCategory
# 0                     7        55-59
# 1                    12  80 or older
# 2                     9        65-69
# 3                    11        75-79
# 4                     4        40-44
# ...                 ...          ...
# 319790                8        60-64
# 319791                3        35-39
# 319792                5        45-49
# 319793                1        25-29
# 319794               12  80 or older
#
# [319795 rows x 2 columns]

# %%
heart_data[['Race_enc','Race']]
# Out:
#         Race_enc      Race
# 0              5     White
# 1              5     White
# 2              5     White
# 3              5     White
# 4              5     White
# ...          ...       ...
# 319790         3  Hispanic
# 319791         3  Hispanic
# 319792         3  Hispanic
# 319793         3  Hispanic
# 319794         3  Hispanic
#
# [319795 rows x 2 columns]

# %%
heart_data[['Diabetic_enc','Diabetic']]
# Out:
#         Diabetic_enc Diabetic
# 0                  2      Yes
# 1                  0       No
# 2                  2      Yes
# 3                  0       No
# 4                  0       No
# ...              ...      ...
# 319790             2      Yes
# 319791             0       No
# 319792             0       No
# 319793             0       No
# 319794             0       No
#
# [319795 rows x 2 columns]

# %%
heart_data[['PhysicalActivity_enc','PhysicalActivity']]
# Out:
#         PhysicalActivity_enc PhysicalActivity
# 0                          1              Yes
# 1                          1              Yes
# 2                          1              Yes
# 3                          0               No
# 4                          1              Yes
# ...                      ...              ...
# 319790                     0               No
# 319791                     1              Yes
# 319792                     1              Yes
# 319793                     0               No
# 319794                     1              Yes
#
# [319795 rows x 2 columns]

# %%
heart_data[['GenHealth_enc','GenHealth']]
# Out:
#         GenHealth_enc  GenHealth
# 0                   4  Very good
# 1                   4  Very good
# 2                   1       Fair
# 3                   2       Good
# 4                   4  Very good
# ...               ...        ...
# 319790              1       Fair
# 319791              4  Very good
# 319792              2       Good
# 319793              2       Good
# 319794              2       Good
#
# [319795 rows x 2 columns]

# %%
heart_data[['Asthma_enc','Asthma']]
# Out:
#         Asthma_enc Asthma
# 0                1    Yes
# 1                0     No
# 2                1    Yes
# 3                0     No
# 4                0     No
# ...            ...    ...
# 319790           1    Yes
# 319791           1    Yes
# 319792           0     No
# 319793           0     No
# 319794           0     No
#
# [319795 rows x 2 columns]

# %%
heart_data[['KidneyDisease_enc','KidneyDisease']]
# Out:
#         KidneyDisease_enc KidneyDisease
# 0                       0            No
# 1                       0            No
# 2                       0            No
# 3                       0            No
# 4                       0            No
# ...                   ...           ...
# 319790                  0            No
# 319791                  0            No
# 319792                  0            No
# 319793                  0            No
# 319794                  0            No
#
# [319795 rows x 2 columns]

# %%
heart_data[['SkinCancer_enc','SkinCancer']]
# Out:
#         SkinCancer_enc SkinCancer
# 0                    1        Yes
# 1                    0         No
# 2                    0         No
# 3                    1        Yes
# 4                    0         No
# ...                ...        ...
# 319790               0         No
# 319791               0         No
# 319792               0         No
# 319793               0         No
# 319794               0         No
#
# [319795 rows x 2 columns]

# %%
comparision = heart_data['Asthma'].value_counts()
comparision
# Out:
# Asthma
# No     276923
# Yes     42872
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
plt.bar(comparision.index, comparision.values)
plt.xlabel('Asthma')
plt.ylabel('Count')
plt.title('Comparision')
plt.show()

# %%
comparision = heart_data['GenHealth'].value_counts()
comparision
# Out:
# GenHealth
# Very good    114150
# Good          92969
# Excellent     66774
# Fair          34624
# Poor          11278
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
plt.bar(comparision.index, comparision.values)
plt.title('GenHealth')
plt.show()

# %%
comparision = heart_data['Race'].value_counts()
comparision
# Out:
# Race
# White                             245228
# Hispanic                           27446
# Black                              22923
# Other                              10928
# Asian                               8068
# American Indian/Alaskan Native      5202
# Name: count, dtype: int64

# %%
plt.bar(comparision.index, comparision.values)
plt.title('Race Comparision')
plt.show()

# %%
comparision = heart_data['Smoking'].value_counts()
comparision
# Out:
# Smoking
# No     187917
# Yes    131878
# Name: count, dtype: int64

# %%
plt.bar(comparision.index, comparision.values)
plt.title('Comparision')
plt.xlabel('smoking')
plt.show()

# %%
plt.scatter(heart_data['Smoking'],heart_data['BMI'])
plt.title("Smoking vs BMI")
plt.xlabel('BMI')
plt.ylabel('Smoking')
plt.show()

# %%
comparision = heart_data['BMI'].value_counts()
comparision
# Out:
# BMI
# 26.63    3768
# 27.46    2767
# 27.44    2723
# 24.41    2696
# 27.12    2525
#          ...
# 59.85       1
# 50.59       1
# 92.53       1
# 62.95       1
# 46.56       1
# Name: count, Length: 3604, dtype: int64

# %%
plt.bar(comparision.index, comparision.values)
plt.title('Comparision')
plt.xlabel('BMI')
plt.show()

# %%
heart_data=pd.read_csv("heart_disease.csv")
